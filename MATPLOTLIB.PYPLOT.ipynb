# %%
import matplotlib.pyplot as plt 
Days = ['Mon','Tue','Wed','thu','Fri','Sat','sun']
Sales = [250,300,280,350,400,420,380]
plt.plot(Days,Sales,color = 'blue')
plt.title('Linechart')
plt.show()

# %%
import matplotlib.pyplot as plt 
Days = ['Mon','Tue','Wed','thu','Fri','Sat','sun']
Sales1 = [250,300,280,350,400,420,380]
Sales2 = [500,600,800,200,400,300,350]
plt.plot(Days,Sales1,color = 'green')
plt.plot(Sales2,color = 'blue',linestyle = '--')
plt.title('Linechart')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.legend()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12452\4147506174.py:10: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
import matplotlib.pyplot as plt     
import numpy as np   
 
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
 
x, y = np.meshgrid(x, y)
z = np.sin(np.sqrt(x**2+y**2))
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x, y, z, camp='viridis')

ax.set_axis_off()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 11
#       9 fig = plt.figure()
#      10 ax = fig.add_subplot(111, projection='3d')
# ---> 11 ax.plot_surface(x, y, z, camp='viridis')
#      13 ax.set_axis_off()
#      14 plt.show()
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\mpl_toolkits\mplot3d\axes3d.py:2315, in Axes3D.plot_surface(self, X, Y, Z, norm, vmin, vmax, lightsource, axlim_clip, **kwargs)
#    2312         color = self._get_lines.get_next_color()
#    2313     color = np.array(mcolors.to_rgba(color))
# -> 2315     polyc = art3d.Poly3DCollection(
#    2316         polys, facecolors=color, shade=shade, lightsource=lightsource,
#    2317         axlim_clip=axlim_clip, **kwargs)
#    2319 self.add_collection(polyc)
#    2320 self.auto_scale_xyz(X, Y, Z, had_data)
#
# ...

# %%
import matplotlib.pyplot as plt     
import numpy as np   
 
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
 
x, y = np.meshgrid(x, y)
z = np.sin(np.sqrt(x**2 + y**2))

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Correct parameter is 'cmap', not 'cp'
ax.plot_surface(x, y, z, cmap='viridis')

ax.set_axis_off()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create mesh grid for spherical coordinates
phi, theta = np.mgrid[0:np.pi:30j, 0:2*np.pi:30j]

# Convert spherical to Cartesian coordinates
x = np.sin(phi) * np.cos(theta)
y = np.sin(phi) * np.sin(theta)
z = np.cos(phi)

# Plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_wireframe(x, y, z, color="cyan")

plt.show()
